# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
## The downloader for Data Processing in Python midterm

# %%
class MidtermDownloader:    
    '''
        Class for downloading the characters and books for midterm purpose.
    '''
    def __init__(self, url):
        
        # Running the functions
        self.url = url
        self.soup = self.getSoup(self.url)
        self.links = self.getLinks(self.soup)
        self.characters = [self.getChars(link) for link in links]
        
        # Saving the results to Pandas DataFrame
        self.dataframe = self.saveToPandas(self.characters)
  

    def getSoup(self, url):
        '''
            Getting the soup from BeautifulSoup.
        '''
        
        r = requests.get(url)
        r.encoding = 'UTF-8'
        return BeautifulSoup(r.text,'lxml')

    
    def getLinks(self, soup):
        '''
            Getting the links for wanted characters.
        '''
        
        lis = soup.find('span',{'id':'Unseen_University_and_the_Wizards'}).parent.previous.previous.parent.parent.parent.find_all('li')

        links = []
        for l in lis:
            link = "http://wiki.lspace.org" + l.find('a')['href']
            links.append(link)

        return links
    
    
    def getChars(self, link):
        '''
            Getting the name and books for a given character (link).
        '''
        
        soup = getSoup(link)
        name = soup.find(id='firstHeading').text

        books = [i.text for i in soup.select("td a[href*='Book:']")]

        chars = {
            'Name': name,
            'Books': books
        }

        return chars
   

    def saveToPandas(self, chars):
        '''
            Saving all data to Pandas DataFrame.
        '''
        
        rows = [] 
        for data in chars: 
            books = data['Books'] 
            name = data['Name'] 

            for book in books:
                row = {'character_name':name, 'book':book}
                rows.append(row)

        return pd.DataFrame(rows)
    
    
    
# Dowloading according to the midterm assignment  
url = "http://wiki.lspace.org/mediawiki/List_of_Pratchett_characters"
md = MidtermDownloader(url)
md.dataframe
# Out:
#                       book                                character_name
# 0               Reaper Man                                   Evadne Cake
# 1              Men at Arms                                   Evadne Cake
# 2                    Jingo                                   Evadne Cake
# 3             Going Postal                                   Evadne Cake
# 4             Making Money                                   Evadne Cake
# 5          Guards! Guards!                                    Fred Colon
# 6              Men at Arms                                    Fred Colon
# 7               Soul Music                                    Fred Colon
# 8             Feet of Clay                                    Fred Colon
# 9                    Jingo                                    Fred Colon
# 10      The Fifth Elephant                                    Fred Colon
# 11               The Truth                                    Fred Colon
# 12           The Last Hero                                    Fred Colon
# 13             Night Watch                                    Fred Colon
# 14                   Thud!                                    Fred Colon
# 15     The Colour of Magic                                    Fred Colon
# 16            Going Postal                                    Fred Colon
# 17            Making Money                                    Fred Colon
# 18              Soul Music                          Marietta Cosmopilite
# 19         Moving Pictures                          Marietta Cosmopilite
# 20              Small Gods                          Marietta Cosmopilite
# 21           Thief of Time                          Marietta Cosmopilite
# 22         Guards! Guards!                                      Detritus
# 23         Moving Pictures                                      Detritus
# 24             Men at Arms                                      Detritus
# 25            Feet of Clay                                      Detritus
# 26                   Jingo                                      Detritus
# 27      The Fifth Elephant                                      Detritus
# 28                   Thud!                                      Detritus
# 29              Soul Music                                      Detritus
# ..                     ...                                           ...
# 169                  Thud!                                  Samuel Vimes
# 170        Guards! Guards!                                  Samuel Vimes
# 171            Men at Arms                                  Samuel Vimes
# 172           Feet of Clay                                  Samuel Vimes
# 173                  Jingo                                  Samuel Vimes
# 174     The Fifth Elephant                                  Samuel Vimes
# 175            Night Watch                                  Samuel Vimes
# 176     Monstrous Regiment                                  Samuel Vimes
# 177                  Thud!                                  Samuel Vimes
# 178        Where's My Cow?                                  Samuel Vimes
# 179                  Snuff                                  Samuel Vimes
# 180          Raising Steam                                  Samuel Vimes
# 181              The Truth                                  Samuel Vimes
# 182           Going Postal                                  Samuel Vimes
# 183           Making Money                                  Samuel Vimes
# 184     Unseen Academicals                                  Samuel Vimes
# 185  I Shall Wear Midnight                                  Samuel Vimes
# 186           Feet of Clay  Visit-The-Infidel-With-Explanatory-Pamphlets
# 187                  Jingo  Visit-The-Infidel-With-Explanatory-Pamphlets
# 188              Hogfather  Visit-The-Infidel-With-Explanatory-Pamphlets
# 189     The Fifth Elephant  Visit-The-Infidel-With-Explanatory-Pamphlets
# 190                  Thud!  Visit-The-Infidel-With-Explanatory-Pamphlets
# 191            Night Watch  Visit-The-Infidel-With-Explanatory-Pamphlets
# 192            Men at Arms                                     Willikins
# 193           Feet of Clay                                     Willikins
# 194                  Jingo                                     Willikins
# 195     The Fifth Elephant                                     Willikins
# 196            Night Watch                                     Willikins
# 197                  Thud!                                     Willikins
# 198                  Snuff                                     Willikins
#
# [199 rows x 2 columns]

# %%
df = md.dataframe

## Task 3a
book = df['book'] == "Men at Arms"
df[book].count()
# --> Answer: 14
# Out:
# book              14
# character_name    14
# dtype: int64

# %%
## Task 3b
chars = (df['character_name'] == "Visit-The-Infidel-With-Explanatory-Pamphlets") | (df['character_name'] == "Evadne Cake")
df[chars].groupby(['book']).count()
# --> Answer: 1 (Jingo)
# Out:
#                     character_name
# book
# Feet of Clay                     1
# Going Postal                     1
# Hogfather                        1
# Jingo                            2
# Making Money                     1
# Men at Arms                      1
# Night Watch                      1
# Reaper Man                       1
# The Fifth Elephant               1
# Thud!                            1
